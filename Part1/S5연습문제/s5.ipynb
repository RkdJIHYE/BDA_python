# %%
import numpy as np

# %%
# 하나의 숫자를 입력받아 10을 곱한 결과를 반환하는 함수 
# mulitply_by_ten 을 작성하시오.
# 기본값은 7로 설정하고, 기본값으로 호출한 결과와 5를 입력하여 호출한 결과를 더한 값을 출력하시오.

def mulitply_by_ten(x=7):
    return x*10

print(mulitply_by_ten())
print(mulitply_by_ten(5))
# Out:
# 70
# 50

# %%
print("Hello World")
# Out:
# Hello World

# %%
city_name ="서울"
age=24
is_student="No"

print(city_name)
print(age)
print(is_student)
# Out:
# 서울
# 24
# No

# %%
x=12
y=4

print((x-y)*y/x)
print(x**y//x)
print((x%y)+2)
# Out:
# 2.6666666666666665
# 1728
# 2

# %%
price =12000
quantity = 3

total_price = price*quantity

if 10000<=total_price<=50000:
    print(True)
else:
    print(False)
# Out:
# True
